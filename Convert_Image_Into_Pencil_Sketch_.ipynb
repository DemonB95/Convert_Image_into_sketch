# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img=cv2.imread('Virat.png')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=350x509 at 0x7F5093DB1050>

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=350x509 at 0x7F5093DA9810>

# %%
img_invert=cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=350x509 at 0x7F5093D9E790>

# %%
img_smoothing=cv2.GaussianBlur(img_invert,(21,21),sigmaX=0,sigmaY=0)

# %%
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=350x509 at 0x7F5093D9BF90>

# %%
def dodgev2(x,y):
    return cv2.divide(x,255-y,scale=256)

# %%
final_img=dodgev2(img_gray,img_smoothing)

# %%
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=350x509 at 0x7F5094DEEB50>

# %%
cv2.imwrite('virat_sketch.png',final_img)
# Out:
# True
